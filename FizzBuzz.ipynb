# %%
mydict = {5:'Fizz',7:'Buzz',11:'Jazz'}

for x in range(1,100):
    out_string = ''
    if x%5==0:
        out_string += 'Fizz'
    if x%7==0:
        out_string += 'Buzz'
    if x%11==0:
        out_string += 'Jazz'
    if len(out_string)==0:
        out_string += str(x)
    print(out_string)
# Out:
# 1
# 2
# 3
# 4
# Fizz
# 6
# Buzz
# 8
# 9
# Fizz
# Jazz
# 12
# 13
# Buzz
# Fizz
# 16
# 17
# 18
# 19
# Fizz
# Buzz
# Jazz
# 23
# 24
# Fizz
# 26
# 27
# Buzz
# 29
# Fizz
# 31
# 32
# Jazz
# 34
# FizzBuzz
# 36
# 37
# 38
# 39
# Fizz
# 41
# Buzz
# 43
# Jazz
# Fizz
# 46
# 47
# 48
# Buzz
# Fizz
# 51
# 52
# 53
# 54
# FizzJazz
# Buzz
# 57
# 58
# 59
# Fizz
# 61
# 62
# Buzz
# 64
# Fizz
# Jazz
# 67
# 68
# 69
# FizzBuzz
# 71
# 72
# 73
# 74
# Fizz
# 76
# BuzzJazz
# 78
# 79
# Fizz
# 81
# 82
# 83
# Buzz
# Fizz
# 86
# 87
# Jazz
# 89
# Fizz
# Buzz
# 92
# 93
# 94
# Fizz
# 96
# 97
# Buzz
# Jazz
